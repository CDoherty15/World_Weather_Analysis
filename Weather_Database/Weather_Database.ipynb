# %%
# Import dependecies
import pandas as pd
import numpy as np
import random
import requests
from config import weather_api_key
from citipy import citipy
from datetime import datetime

# %%
# create a set of random lat and long combos
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-90.000, high=90.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities 
cities = []
# ID the nearest city for each lat and long combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # if city is unique, then add it to cities list
    if city not in cities:
        cities.append(city)
# print the city count ot confirm sufficient count
len(cities)
# Out:
# 725

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# 2.
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
#        breakpoint()
        city_weather_desc = city_weather["weather"][0]["description"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                           "Weather Desc": city_weather_desc,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hambantota
# Processing Record 2 of Set 1 | ushuaia
# Processing Record 3 of Set 1 | ludvika
# Processing Record 4 of Set 1 | botucatu
# Processing Record 5 of Set 1 | kalengwa
# Processing Record 6 of Set 1 | port-gentil
# Processing Record 7 of Set 1 | dikson
# Processing Record 8 of Set 1 | vila franca do campo
# Processing Record 9 of Set 1 | bubaque
# Processing Record 10 of Set 1 | elizabeth city
# Processing Record 11 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 1 | moldova noua
# Processing Record 13 of Set 1 | vardo
# Processing Record 14 of Set 1 | port elizabeth
# Processing Record 15 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 16 of Set 1 | ilulissat
# Processing Record 17 of Set 1 | salalah
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | lagoa
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | linhares
# Processing Record 24 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 1 | hammerfest
# Processing Record 26 of Set 1 | arraial do cabo
# Processing Record 27 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 1 | ginir
# Processing Record 29 of Set 1 | llangefni
# Processing Record 30 of Set 1 | bafia
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | tarko-sale
# Processing Record 33 of Set 1 | sambava
# Processing Record 34 of Set 1 | ponta do sol
# Processing Record 35 of Set 1 | puerto el triunfo
# Processing Record 36 of Set 1 | jacareacanga
# Processing Record 37 of Set 1 | iquitos
# Processing Record 38 of Set 1 | torit
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | bargal
# City not found. Skipping...
# Processing Record 41 of Set 1 | halifax
# Processing Record 42 of Set 1 | esmeralda
# Processing Record 43 of Set 1 | pisco
# Processing Record 44 of Set 1 | punta arenas
# Processing Record 45 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 1 | sao filipe
# Processing Record 47 of Set 1 | misratah
# Processing Record 48 of Set 1 | rawson
# Processing Record 49 of Set 1 | buraydah
# Processing Record 50 of Set 1 | upernavik
# Processing Record 1 of Set 2 | mehamn
# Processing Record 2 of Set 2 | soyo
# Processing Record 3 of Set 2 | louisbourg
# City not found. Skipping...
# Processing Record 4 of Set 2 | sorland
# Processing Record 5 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 2 | huarmey
# Processing Record 7 of Set 2 | santarem
# Processing Record 8 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 2 | jiwani
# Processing Record 10 of Set 2 | bredasdorp
# Processing Record 11 of Set 2 | adrar
# Processing Record 12 of Set 2 | pedernales
# Processing Record 13 of Set 2 | awassa
# Processing Record 14 of Set 2 | los llanos de aridane
# Processing Record 15 of Set 2 | saint-augustin
# Processing Record 16 of Set 2 | semey
# Processing Record 17 of Set 2 | dudinka
# Processing Record 18 of Set 2 | gat
# Processing Record 19 of Set 2 | san juan del cesar
# Processing Record 20 of Set 2 | luangwa
# Processing Record 21 of Set 2 | vila velha
# Processing Record 22 of Set 2 | vytegra
# Processing Record 23 of Set 2 | hobyo
# Processing Record 24 of Set 2 | kavaratti
# Processing Record 25 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 2 | shache
# Processing Record 27 of Set 2 | san juan
# Processing Record 28 of Set 2 | muros
# Processing Record 29 of Set 2 | nanortalik
# Processing Record 30 of Set 2 | slatina
# Processing Record 31 of Set 2 | plouzane
# Processing Record 32 of Set 2 | bundu
# Processing Record 33 of Set 2 | kruisfontein
# Processing Record 34 of Set 2 | neyshabur
# Processing Record 35 of Set 2 | le port
# Processing Record 36 of Set 2 | ribeira grande
# Processing Record 37 of Set 2 | shubarshi
# Processing Record 38 of Set 2 | klaksvik
# Processing Record 39 of Set 2 | saint-philippe
# Processing Record 40 of Set 2 | chuy
# Processing Record 41 of Set 2 | clyde river
# Processing Record 42 of Set 2 | prata
# Processing Record 43 of Set 2 | caravelas
# Processing Record 44 of Set 2 | tasiilaq
# Processing Record 45 of Set 2 | touros
# Processing Record 46 of Set 2 | necochea
# Processing Record 47 of Set 2 | saldanha
# Processing Record 48 of Set 2 | thinadhoo
# Processing Record 49 of Set 2 | victoria
# Processing Record 50 of Set 2 | agucadoura
# Processing Record 1 of Set 3 | laguna
# Processing Record 2 of Set 3 | bayan
# Processing Record 3 of Set 3 | niwari
# Processing Record 4 of Set 3 | amapa
# Processing Record 5 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 3 | grande-riviere
# City not found. Skipping...
# Processing Record 7 of Set 3 | ardakan
# Processing Record 8 of Set 3 | santiago del estero
# Processing Record 9 of Set 3 | kyshtovka
# Processing Record 10 of Set 3 | saint george
# Processing Record 11 of Set 3 | mahebourg
# Processing Record 12 of Set 3 | saint-georges
# Processing Record 13 of Set 3 | zarate
# Processing Record 14 of Set 3 | chute-aux-outardes
# Processing Record 15 of Set 3 | diffa
# Processing Record 16 of Set 3 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 17 of Set 3 | jalu
# Processing Record 18 of Set 3 | maniitsoq
# Processing Record 19 of Set 3 | lima
# Processing Record 20 of Set 3 | concordia
# Processing Record 21 of Set 3 | cuenca
# Processing Record 22 of Set 3 | longyearbyen
# Processing Record 23 of Set 3 | tollose
# Processing Record 24 of Set 3 | wadi musa
# Processing Record 25 of Set 3 | praia da vitoria
# Processing Record 26 of Set 3 | araripe
# Processing Record 27 of Set 3 | abdulino
# Processing Record 28 of Set 3 | faya
# Processing Record 29 of Set 3 | lethem
# Processing Record 30 of Set 3 | luderitz
# Processing Record 31 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 32 of Set 3 | owerri
# Processing Record 33 of Set 3 | walvis bay
# Processing Record 34 of Set 3 | taltal
# Processing Record 35 of Set 3 | iisaku
# Processing Record 36 of Set 3 | harper
# Processing Record 37 of Set 3 | grindavik
# Processing Record 38 of Set 3 | hvide sande
# Processing Record 39 of Set 3 | bara
# Processing Record 40 of Set 3 | portobelo
# Processing Record 41 of Set 3 | port alfred
# Processing Record 42 of Set 3 | coquimbo
# Processing Record 43 of Set 3 | bathsheba
# Processing Record 44 of Set 3 | torbay
# Processing Record 45 of Set 3 | atar
# Processing Record 46 of Set 3 | mizque
# Processing Record 47 of Set 3 | wa
# City not found. Skipping...
# Processing Record 48 of Set 3 | arlit
# Processing Record 49 of Set 3 | hofn
# Processing Record 50 of Set 3 | aras
# Processing Record 1 of Set 4 | bambous virieux
# Processing Record 2 of Set 4 | beyneu
# Processing Record 3 of Set 4 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 4 | san luis
# Processing Record 5 of Set 4 | chikmagalur
# Processing Record 6 of Set 4 | qasigiannguit
# Processing Record 7 of Set 4 | acarau
# Processing Record 8 of Set 4 | passo de camaragibe
# Processing Record 9 of Set 4 | janakpur
# Processing Record 10 of Set 4 | khandbari
# Processing Record 11 of Set 4 | vredendal
# Processing Record 12 of Set 4 | maues
# Processing Record 13 of Set 4 | stulovo
# Processing Record 14 of Set 4 | carnarvon
# Processing Record 15 of Set 4 | marathon
# Processing Record 16 of Set 4 | copacabana
# Processing Record 17 of Set 4 | matay
# Processing Record 18 of Set 4 | ponta delgada
# Processing Record 19 of Set 4 | am timan
# Processing Record 20 of Set 4 | mitsamiouli
# Processing Record 21 of Set 4 | taoudenni
# Processing Record 22 of Set 4 | sao gabriel da cachoeira
# Processing Record 23 of Set 4 | huaraz
# Processing Record 24 of Set 4 | bilma
# Processing Record 25 of Set 4 | usinsk
# Processing Record 26 of Set 4 | amsterdam
# Processing Record 27 of Set 4 | hamilton
# Processing Record 28 of Set 4 | qeshm
# Processing Record 29 of Set 4 | itarema
# Processing Record 30 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 31 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 32 of Set 4 | margate
# Processing Record 33 of Set 4 | levokumskoye
# Processing Record 34 of Set 4 | le moule
# Processing Record 35 of Set 4 | otanche
# Processing Record 36 of Set 4 | port hawkesbury
# Processing Record 37 of Set 4 | georgetown
# Processing Record 38 of Set 4 | porto novo
# Processing Record 39 of Set 4 | tuni
# Processing Record 40 of Set 4 | lebu
# Processing Record 41 of Set 4 | mar del plata
# Processing Record 42 of Set 4 | puerto del rosario
# Processing Record 43 of Set 4 | irara
# Processing Record 44 of Set 4 | lugovskoy
# Processing Record 45 of Set 4 | unai
# Processing Record 46 of Set 4 | americus
# Processing Record 47 of Set 4 | yar-sale
# Processing Record 48 of Set 4 | manali
# Processing Record 49 of Set 4 | wenchi
# Processing Record 50 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 5 | souillac
# Processing Record 2 of Set 5 | mayumba
# Processing Record 3 of Set 5 | ibipeba
# Processing Record 4 of Set 5 | san cristobal
# Processing Record 5 of Set 5 | codrington
# Processing Record 6 of Set 5 | san nicolas
# Processing Record 7 of Set 5 | narsaq
# Processing Record 8 of Set 5 | rio gallegos
# Processing Record 9 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 10 of Set 5 | markivka
# Processing Record 11 of Set 5 | jam sahib
# Processing Record 12 of Set 5 | calahorra
# Processing Record 13 of Set 5 | santa fe
# Processing Record 14 of Set 5 | iracoubo
# Processing Record 15 of Set 5 | palencia
# Processing Record 16 of Set 5 | sabha
# Processing Record 17 of Set 5 | alta floresta
# Processing Record 18 of Set 5 | talawdi
# City not found. Skipping...
# Processing Record 19 of Set 5 | abu kamal
# Processing Record 20 of Set 5 | bonfim
# Processing Record 21 of Set 5 | yeletskiy
# City not found. Skipping...
# Processing Record 22 of Set 5 | quatre cocos
# Processing Record 23 of Set 5 | thyboron
# Processing Record 24 of Set 5 | alghero
# Processing Record 25 of Set 5 | kenscoff
# Processing Record 26 of Set 5 | bilaspur
# Processing Record 27 of Set 5 | castro
# Processing Record 28 of Set 5 | kallithea
# Processing Record 29 of Set 5 | hithadhoo
# Processing Record 30 of Set 5 | lokosovo
# Processing Record 31 of Set 5 | paamiut
# Processing Record 32 of Set 5 | khorol
# Processing Record 33 of Set 5 | hyeres
# Processing Record 34 of Set 5 | strzegom
# Processing Record 35 of Set 5 | mao
# Processing Record 36 of Set 5 | iqaluit
# Processing Record 37 of Set 5 | abu jubayhah
# City not found. Skipping...
# Processing Record 38 of Set 5 | brae
# Processing Record 39 of Set 5 | luanda
# Processing Record 40 of Set 5 | araouane
# Processing Record 41 of Set 5 | ostrovnoy
# Processing Record 42 of Set 5 | saint anthony
# Processing Record 43 of Set 5 | tutoia
# Processing Record 44 of Set 5 | don benito
# Processing Record 45 of Set 5 | cidreira
# Processing Record 46 of Set 5 | boyabat
# Processing Record 47 of Set 5 | makushino
# Processing Record 48 of Set 5 | kangaatsiaq
# Processing Record 49 of Set 5 | santa rosa
# Processing Record 50 of Set 5 | kahama
# Processing Record 1 of Set 6 | ngama
# Processing Record 2 of Set 6 | aleksandrov gay
# Processing Record 3 of Set 6 | santiago de cuba
# Processing Record 4 of Set 6 | shebalino
# Processing Record 5 of Set 6 | erice
# Processing Record 6 of Set 6 | sao jose da coroa grande
# Processing Record 7 of Set 6 | bereda
# Processing Record 8 of Set 6 | matara
# Processing Record 9 of Set 6 | tres arroyos
# Processing Record 10 of Set 6 | thompson
# Processing Record 11 of Set 6 | awbari
# Processing Record 12 of Set 6 | neiba
# Processing Record 13 of Set 6 | machico
# Processing Record 14 of Set 6 | rock sound
# Processing Record 15 of Set 6 | havoysund
# Processing Record 16 of Set 6 | kilrush
# Processing Record 17 of Set 6 | tashtyp
# Processing Record 18 of Set 6 | yola
# Processing Record 19 of Set 6 | dingle
# Processing Record 20 of Set 6 | caceres
# Processing Record 21 of Set 6 | machiques
# Processing Record 22 of Set 6 | capiibary
# Processing Record 23 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 6 | mrirt
# City not found. Skipping...
# Processing Record 25 of Set 6 | monrovia
# Processing Record 26 of Set 6 | upata
# Processing Record 27 of Set 6 | weligama
# Processing Record 28 of Set 6 | marystown
# Processing Record 29 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 30 of Set 6 | aswan
# Processing Record 31 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 6 | qaqortoq
# Processing Record 33 of Set 6 | biltine
# Processing Record 34 of Set 6 | kuruman
# Processing Record 35 of Set 6 | sechura
# Processing Record 36 of Set 6 | san ignacio
# Processing Record 37 of Set 6 | sidi ali
# Processing Record 38 of Set 6 | vetluga
# Processing Record 39 of Set 6 | romny
# Processing Record 40 of Set 6 | puerto cabezas
# Processing Record 41 of Set 6 | coulihaut
# City not found. Skipping...
# Processing Record 42 of Set 6 | vestmannaeyjar
# Processing Record 43 of Set 6 | labytnangi
# Processing Record 44 of Set 6 | asosa
# Processing Record 45 of Set 6 | viedma
# Processing Record 46 of Set 6 | kaffrine
# Processing Record 47 of Set 6 | henties bay
# Processing Record 48 of Set 6 | palmas del socorro
# Processing Record 49 of Set 6 | grodzisk wielkopolski
# Processing Record 50 of Set 6 | belyy yar
# Processing Record 1 of Set 7 | shihezi
# Processing Record 2 of Set 7 | cap malheureux
# Processing Record 3 of Set 7 | oranjemund
# Processing Record 4 of Set 7 | stadskanaal
# Processing Record 5 of Set 7 | salinopolis
# Processing Record 6 of Set 7 | alcudia
# Processing Record 7 of Set 7 | shimoni
# Processing Record 8 of Set 7 | cayenne
# Processing Record 9 of Set 7 | aljezur
# Processing Record 10 of Set 7 | oranjestad
# Processing Record 11 of Set 7 | beira
# Processing Record 12 of Set 7 | young
# Processing Record 13 of Set 7 | pergamino
# Processing Record 14 of Set 7 | ilyich
# Processing Record 15 of Set 7 | olinda
# Processing Record 16 of Set 7 | businga
# Processing Record 17 of Set 7 | huittinen
# Processing Record 18 of Set 7 | montepuez
# Processing Record 19 of Set 7 | gao
# Processing Record 20 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 7 | darab
# Processing Record 22 of Set 7 | antofagasta
# Processing Record 23 of Set 7 | la rioja
# Processing Record 24 of Set 7 | panaba
# Processing Record 25 of Set 7 | mahbubnagar
# Processing Record 26 of Set 7 | azul
# Processing Record 27 of Set 7 | catabola
# Processing Record 28 of Set 7 | la palma
# Processing Record 29 of Set 7 | kautokeino
# Processing Record 30 of Set 7 | mangai
# Processing Record 31 of Set 7 | kisanga
# Processing Record 32 of Set 7 | goderich
# Processing Record 33 of Set 7 | barra
# Processing Record 34 of Set 7 | maldonado
# Processing Record 35 of Set 7 | bluefields
# Processing Record 36 of Set 7 | lodwar
# Processing Record 37 of Set 7 | gantt
# Processing Record 38 of Set 7 | husavik
# Processing Record 39 of Set 7 | keti bandar
# Processing Record 40 of Set 7 | boa vista
# Processing Record 41 of Set 7 | nicoya
# Processing Record 42 of Set 7 | brits
# Processing Record 43 of Set 7 | gazanjyk
# Processing Record 44 of Set 7 | baijiantan
# Processing Record 45 of Set 7 | pachino
# Processing Record 46 of Set 7 | makaleng
# Processing Record 47 of Set 7 | marsa matruh
# Processing Record 48 of Set 7 | chilca
# Processing Record 49 of Set 7 | bonavista
# Processing Record 50 of Set 7 | bure
# Processing Record 1 of Set 8 | makurdi
# Processing Record 2 of Set 8 | general pico
# Processing Record 3 of Set 8 | mitu
# Processing Record 4 of Set 8 | bud
# Processing Record 5 of Set 8 | toktogul
# Processing Record 6 of Set 8 | beloha
# Processing Record 7 of Set 8 | varna
# Processing Record 8 of Set 8 | gayeri
# Processing Record 9 of Set 8 | gaeta
# Processing Record 10 of Set 8 | richards bay
# Processing Record 11 of Set 8 | methoni
# Processing Record 12 of Set 8 | lasa
# Processing Record 13 of Set 8 | pangnirtung
# Processing Record 14 of Set 8 | bandarbeyla
# Processing Record 15 of Set 8 | alta
# Processing Record 16 of Set 8 | gorele
# Processing Record 17 of Set 8 | sucua
# Processing Record 18 of Set 8 | stokmarknes
# Processing Record 19 of Set 8 | sakakah
# Processing Record 20 of Set 8 | honningsvag
# Processing Record 21 of Set 8 | key largo
# Processing Record 22 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 23 of Set 8 | kuytun
# Processing Record 24 of Set 8 | comodoro rivadavia
# Processing Record 25 of Set 8 | andenes
# Processing Record 26 of Set 8 | ancud
# Processing Record 27 of Set 8 | bodajk
# Processing Record 28 of Set 8 | roald
# Processing Record 29 of Set 8 | puerto quijarro
# Processing Record 30 of Set 8 | sao joao da barra
# Processing Record 31 of Set 8 | matagami
# Processing Record 32 of Set 8 | oda
# Processing Record 33 of Set 8 | mmabatho
# Processing Record 34 of Set 8 | kattivakkam
# Processing Record 35 of Set 8 | pitimbu
# Processing Record 36 of Set 8 | ntchisi
# Processing Record 37 of Set 8 | yarmolyntsi
# Processing Record 38 of Set 8 | nioro
# Processing Record 39 of Set 8 | sinkat
# City not found. Skipping...
# Processing Record 40 of Set 8 | chapais
# Processing Record 41 of Set 8 | santa cruz
# Processing Record 42 of Set 8 | say
# Processing Record 43 of Set 8 | staraya stanitsa
# Processing Record 44 of Set 8 | bonthe
# Processing Record 45 of Set 8 | olanchito
# Processing Record 46 of Set 8 | banepa
# Processing Record 47 of Set 8 | buchanan
# Processing Record 48 of Set 8 | cockburn town
# Processing Record 49 of Set 8 | amudat
# Processing Record 50 of Set 8 | dunn
# Processing Record 1 of Set 9 | grand gaube
# Processing Record 2 of Set 9 | tocopilla
# Processing Record 3 of Set 9 | marienburg
# Processing Record 4 of Set 9 | cheuskiny
# City not found. Skipping...
# Processing Record 5 of Set 9 | santa lucia
# Processing Record 6 of Set 9 | waw
# Processing Record 7 of Set 9 | merrill
# Processing Record 8 of Set 9 | lulea
# Processing Record 9 of Set 9 | minna
# Processing Record 10 of Set 9 | inhambane
# Processing Record 11 of Set 9 | carutapera
# Processing Record 12 of Set 9 | urmary
# Processing Record 13 of Set 9 | kalvarija
# Processing Record 14 of Set 9 | chicama
# Processing Record 15 of Set 9 | san andres
# Processing Record 16 of Set 9 | piet retief
# Processing Record 17 of Set 9 | sarahan
# Processing Record 18 of Set 9 | barranca
# Processing Record 19 of Set 9 | fort-shevchenko
# Processing Record 20 of Set 9 | haileybury
# Processing Record 21 of Set 9 | kortkeros
# Processing Record 22 of Set 9 | cazaje
# City not found. Skipping...
# Processing Record 23 of Set 9 | horconcitos
# Processing Record 24 of Set 9 | at-bashi
# Processing Record 25 of Set 9 | antalaha
# Processing Record 26 of Set 9 | jalingo
# Processing Record 27 of Set 9 | tabou
# Processing Record 28 of Set 9 | komatipoort
# Processing Record 29 of Set 9 | bosconia
# Processing Record 30 of Set 9 | ylivieska
# Processing Record 31 of Set 9 | hearst
# Processing Record 32 of Set 9 | jarjis
# City not found. Skipping...
# Processing Record 33 of Set 9 | kashi
# Processing Record 34 of Set 9 | chibuto
# Processing Record 35 of Set 9 | ilhabela
# Processing Record 36 of Set 9 | catamarca
# Processing Record 37 of Set 9 | tiznit
# Processing Record 38 of Set 9 | hualmay
# Processing Record 39 of Set 9 | sterlibashevo
# Processing Record 40 of Set 9 | dakar
# Processing Record 41 of Set 9 | grao mogol
# Processing Record 42 of Set 9 | outjo
# Processing Record 43 of Set 9 | dinsor
# City not found. Skipping...
# Processing Record 44 of Set 9 | tawnat
# City not found. Skipping...
# Processing Record 45 of Set 9 | ballina
# Processing Record 46 of Set 9 | carndonagh
# Processing Record 47 of Set 9 | luba
# Processing Record 48 of Set 9 | salym
# Processing Record 49 of Set 9 | owando
# Processing Record 50 of Set 9 | kushmurun
# Processing Record 1 of Set 10 | escanaba
# Processing Record 2 of Set 10 | farmington
# Processing Record 3 of Set 10 | khartoum
# Processing Record 4 of Set 10 | saint-pierre
# Processing Record 5 of Set 10 | madison
# Processing Record 6 of Set 10 | la asuncion
# Processing Record 7 of Set 10 | atbasar
# Processing Record 8 of Set 10 | aripuana
# Processing Record 9 of Set 10 | port antonio
# Processing Record 10 of Set 10 | geraldton
# Processing Record 11 of Set 10 | mount pleasant
# Processing Record 12 of Set 10 | barvinkove
# Processing Record 13 of Set 10 | chiredzi
# Processing Record 14 of Set 10 | sailana
# Processing Record 15 of Set 10 | tazovskiy
# Processing Record 16 of Set 10 | westpunt
# City not found. Skipping...
# Processing Record 17 of Set 10 | veraval
# Processing Record 18 of Set 10 | mapiripan
# Processing Record 19 of Set 10 | presidencia roque saenz pena
# Processing Record 20 of Set 10 | el hatillo
# Processing Record 21 of Set 10 | sept-iles
# Processing Record 22 of Set 10 | stornoway
# Processing Record 23 of Set 10 | wilmington
# Processing Record 24 of Set 10 | moose factory
# Processing Record 25 of Set 10 | poltava
# Processing Record 26 of Set 10 | chern
# Processing Record 27 of Set 10 | dwarka
# Processing Record 28 of Set 10 | batsfjord
# Processing Record 29 of Set 10 | sayyan
# Processing Record 30 of Set 10 | sochi
# Processing Record 31 of Set 10 | norwich
# Processing Record 32 of Set 10 | bay roberts
# Processing Record 33 of Set 10 | minas novas
# Processing Record 34 of Set 10 | opuwo
# Processing Record 35 of Set 10 | rocha
# Processing Record 36 of Set 10 | bulaevo
# Processing Record 37 of Set 10 | jaciara
# Processing Record 38 of Set 10 | mwanza
# Processing Record 39 of Set 10 | sinnamary
# Processing Record 40 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 41 of Set 10 | krasnoslobodsk
# Processing Record 42 of Set 10 | primorsk
# Processing Record 43 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 44 of Set 10 | mashhad
# Processing Record 45 of Set 10 | mecca
# Processing Record 46 of Set 10 | namibe
# Processing Record 47 of Set 10 | reconquista
# Processing Record 48 of Set 10 | benghazi
# Processing Record 49 of Set 10 | kaduqli
# Processing Record 50 of Set 10 | santa isabel do rio negro
# Processing Record 1 of Set 11 | road town
# Processing Record 2 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 3 of Set 11 | kutum
# Processing Record 4 of Set 11 | san jose del guaviare
# Processing Record 5 of Set 11 | mushie
# Processing Record 6 of Set 11 | atlantic city
# Processing Record 7 of Set 11 | shahrud
# Processing Record 8 of Set 11 | planaltina
# Processing Record 9 of Set 11 | mogadishu
# Processing Record 10 of Set 11 | ercis
# Processing Record 11 of Set 11 | skibbereen
# Processing Record 12 of Set 11 | mercedes
# Processing Record 13 of Set 11 | uivar
# Processing Record 14 of Set 11 | killybegs
# Processing Record 15 of Set 11 | rio cuarto
# Processing Record 16 of Set 11 | kamenka
# Processing Record 17 of Set 11 | axim
# Processing Record 18 of Set 11 | pervomayskoye
# Processing Record 19 of Set 11 | mubende
# Processing Record 20 of Set 11 | urdoma
# Processing Record 21 of Set 11 | calama
# Processing Record 22 of Set 11 | sisimiut
# Processing Record 23 of Set 11 | muslyumovo
# Processing Record 24 of Set 11 | melipilla
# Processing Record 25 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 26 of Set 11 | inta
# Processing Record 27 of Set 11 | keetmanshoop
# Processing Record 28 of Set 11 | cabedelo
# Processing Record 29 of Set 11 | sawakin
# Processing Record 30 of Set 11 | gojra
# Processing Record 31 of Set 11 | witu
# Processing Record 32 of Set 11 | tefe
# Processing Record 33 of Set 11 | chinhoyi
# Processing Record 34 of Set 11 | virton
# Processing Record 35 of Set 11 | wagar
# Processing Record 36 of Set 11 | chivacoa
# Processing Record 37 of Set 11 | kansanshi
# Processing Record 38 of Set 11 | north augusta
# Processing Record 39 of Set 11 | nagorsk
# Processing Record 40 of Set 11 | itacare
# Processing Record 41 of Set 11 | belmonte
# Processing Record 42 of Set 11 | sarande
# Processing Record 43 of Set 11 | palora
# Processing Record 44 of Set 11 | villa maria
# Processing Record 45 of Set 11 | turukhansk
# Processing Record 46 of Set 11 | sur
# Processing Record 47 of Set 11 | naraina
# Processing Record 48 of Set 11 | mabaruma
# Processing Record 49 of Set 11 | male
# Processing Record 50 of Set 11 | werda
# Processing Record 1 of Set 12 | kidodi
# Processing Record 2 of Set 12 | birjand
# Processing Record 3 of Set 12 | tumaco
# Processing Record 4 of Set 12 | lodja
# Processing Record 5 of Set 12 | nalut
# Processing Record 6 of Set 12 | dobryanka
# Processing Record 7 of Set 12 | albany
# Processing Record 8 of Set 12 | lucapa
# Processing Record 9 of Set 12 | kulhudhuffushi
# Processing Record 10 of Set 12 | ormara
# Processing Record 11 of Set 12 | chipinge
# Processing Record 12 of Set 12 | mayor pablo lagerenza
# Processing Record 13 of Set 12 | ampanihy
# Processing Record 14 of Set 12 | berlevag
# Processing Record 15 of Set 12 | anjozorobe
# Processing Record 16 of Set 12 | san rafael del sur
# Processing Record 17 of Set 12 | comendador
# Processing Record 18 of Set 12 | aksarka
# Processing Record 19 of Set 12 | bida
# Processing Record 20 of Set 12 | sombrio
# Processing Record 21 of Set 12 | kudahuvadhoo
# Processing Record 22 of Set 12 | hvolsvollur
# Processing Record 23 of Set 12 | asayita
# City not found. Skipping...
# Processing Record 24 of Set 12 | burgersdorp
# Processing Record 25 of Set 12 | butler
# Processing Record 26 of Set 12 | kuliyapitiya
# Processing Record 27 of Set 12 | susanino
# Processing Record 28 of Set 12 | micheweni
# Processing Record 29 of Set 12 | tessalit
# Processing Record 30 of Set 12 | ullapool
# Processing Record 31 of Set 12 | snezhnogorsk
# Processing Record 32 of Set 12 | tukrah
# Processing Record 33 of Set 12 | leh
# Processing Record 34 of Set 12 | maykain
# City not found. Skipping...
# Processing Record 35 of Set 12 | bukama
# Processing Record 36 of Set 12 | marovoay
# Processing Record 37 of Set 12 | bengkulu
# Processing Record 38 of Set 12 | yangambi
# Processing Record 39 of Set 12 | trincomalee
# Processing Record 40 of Set 12 | bani
# Processing Record 41 of Set 12 | okakarara
# Processing Record 42 of Set 12 | iberia
# Processing Record 43 of Set 12 | crossville
# Processing Record 44 of Set 12 | liverpool
# Processing Record 45 of Set 12 | loandjili
# Processing Record 46 of Set 12 | san ramon de la nueva oran
# Processing Record 47 of Set 12 | mattru
# Processing Record 48 of Set 12 | baherden
# Processing Record 49 of Set 12 | pauini
# Processing Record 50 of Set 12 | florianopolis
# Processing Record 1 of Set 13 | ystad
# Processing Record 2 of Set 13 | kovdor
# Processing Record 3 of Set 13 | qibili
# City not found. Skipping...
# Processing Record 4 of Set 13 | hun
# Processing Record 5 of Set 13 | guru har sahai
# Processing Record 6 of Set 13 | rabo de peixe
# Processing Record 7 of Set 13 | jose bonifacio
# Processing Record 8 of Set 13 | shahreza
# Processing Record 9 of Set 13 | saint-leu
# Processing Record 10 of Set 13 | uspenka
# Processing Record 11 of Set 13 | ladybrand
# Processing Record 12 of Set 13 | kleck
# City not found. Skipping...
# Processing Record 13 of Set 13 | mezen
# Processing Record 14 of Set 13 | pontes e lacerda
# Processing Record 15 of Set 13 | kindu
# Processing Record 16 of Set 13 | coihaique
# Processing Record 17 of Set 13 | rio grande
# Processing Record 18 of Set 13 | puerto carreno
# Processing Record 19 of Set 13 | rognan
# Processing Record 20 of Set 13 | dustlik
# Processing Record 21 of Set 13 | donskoye
# Processing Record 22 of Set 13 | the valley
# Processing Record 23 of Set 13 | benavente
# Processing Record 24 of Set 13 | altamira
# Processing Record 25 of Set 13 | fuerte olimpo
# Processing Record 26 of Set 13 | vila do maio
# Processing Record 27 of Set 13 | felidhoo
# City not found. Skipping...
# Processing Record 28 of Set 13 | mariental
# Processing Record 29 of Set 13 | brewster
# Processing Record 30 of Set 13 | lexington park
# Processing Record 31 of Set 13 | bahia blanca
# Processing Record 32 of Set 13 | ansbach
# Processing Record 33 of Set 13 | kjopsvik
# Processing Record 34 of Set 13 | snasa
# Processing Record 35 of Set 13 | kasangulu
# Processing Record 36 of Set 13 | gobabis
# Processing Record 37 of Set 13 | druzhba
# Processing Record 38 of Set 13 | sete
# Processing Record 39 of Set 13 | parasia
# Processing Record 40 of Set 13 | westerland
# Processing Record 41 of Set 13 | plymouth
# Processing Record 42 of Set 13 | desenzano del garda
# Processing Record 43 of Set 13 | abu samrah
# Processing Record 44 of Set 13 | malangali
# Processing Record 45 of Set 13 | coruripe
# Processing Record 46 of Set 13 | clarence town
# Processing Record 47 of Set 13 | herat
# Processing Record 48 of Set 13 | kelamangalam
# Processing Record 49 of Set 13 | aracaju
# Processing Record 50 of Set 13 | vohibinany
# Processing Record 1 of Set 14 | komsomolskiy
# Processing Record 2 of Set 14 | korla
# Processing Record 3 of Set 14 | urucurituba
# Processing Record 4 of Set 14 | rivadavia
# Processing Record 5 of Set 14 | broadstairs
# Processing Record 6 of Set 14 | guiratinga
# Processing Record 7 of Set 14 | kankon
# Processing Record 8 of Set 14 | akureyri
# Processing Record 9 of Set 14 | polunochnoye
# Processing Record 10 of Set 14 | manakara
# Processing Record 11 of Set 14 | strezhevoy
# Processing Record 12 of Set 14 | tucurui
# Processing Record 13 of Set 14 | san vicente
# Processing Record 14 of Set 14 | asfi
# Processing Record 15 of Set 14 | chingirlau
# Processing Record 16 of Set 14 | tromso
# Processing Record 17 of Set 14 | moba
# Processing Record 18 of Set 14 | medzev
# Processing Record 19 of Set 14 | karakose
# City not found. Skipping...
# Processing Record 20 of Set 14 | oum hadjer
# Processing Record 21 of Set 14 | morshansk
# Processing Record 22 of Set 14 | damaturu
# Processing Record 23 of Set 14 | bulungu
# Processing Record 24 of Set 14 | kozhevnikovo
# Processing Record 25 of Set 14 | tsaratanana
# Processing Record 26 of Set 14 | lixourion
# Processing Record 27 of Set 14 | encruzilhada do sul
# Processing Record 28 of Set 14 | tapes
# Processing Record 29 of Set 14 | markdale
# Processing Record 30 of Set 14 | calvia
# Processing Record 31 of Set 14 | ovalle
# Processing Record 32 of Set 14 | piacabucu
# Processing Record 33 of Set 14 | shu
# Processing Record 34 of Set 14 | padang
# Processing Record 35 of Set 14 | presidente epitacio
# Processing Record 36 of Set 14 | svarstad
# Processing Record 37 of Set 14 | miracatu
# Processing Record 38 of Set 14 | sayat
# Processing Record 39 of Set 14 | karla
# Processing Record 40 of Set 14 | troy
# Processing Record 41 of Set 14 | stilfontein
# Processing Record 42 of Set 14 | ambovombe
# Processing Record 43 of Set 14 | springbok
# Processing Record 44 of Set 14 | isiro
# Processing Record 45 of Set 14 | olafsvik
# Processing Record 46 of Set 14 | cradock
# Processing Record 47 of Set 14 | boksitogorsk
# Processing Record 48 of Set 14 | naron
# Processing Record 49 of Set 14 | ureki
# Processing Record 50 of Set 14 | hit
# Processing Record 1 of Set 15 | kismayo
# Processing Record 2 of Set 15 | vestmanna
# Processing Record 3 of Set 15 | mamallapuram
# Processing Record 4 of Set 15 | sciacca
# Processing Record 5 of Set 15 | sidi bu zayd
# City not found. Skipping...
# Processing Record 6 of Set 15 | oktyabrskoye
# Processing Record 7 of Set 15 | bombay
# Processing Record 8 of Set 15 | sao desiderio
# Processing Record 9 of Set 15 | saint-louis
# Processing Record 10 of Set 15 | zaranj
# Processing Record 11 of Set 15 | praia
# Processing Record 12 of Set 15 | lahij
# Processing Record 13 of Set 15 | sant feliu de guixols
# Processing Record 14 of Set 15 | esmeraldas
# Processing Record 15 of Set 15 | pinas
# Processing Record 16 of Set 15 | yarada
# Processing Record 17 of Set 15 | maraa
# Processing Record 18 of Set 15 | kanniyakumari
# Processing Record 19 of Set 15 | bardiyah
# Processing Record 20 of Set 15 | vetapalem
# Processing Record 21 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 22 of Set 15 | kilindoni
# Processing Record 23 of Set 15 | marawi
# Processing Record 24 of Set 15 | talnakh
# Processing Record 25 of Set 15 | eskasem
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 675

# %%
## 2.
## Create an empty list to hold the weather data.
#city_data = []
## Print the beginning of the logging.
#print("Beginning Data Retrieval     ")
#print("-----------------------------")
#
## Create counters.
#record_count = 1
#set_count = 1
#
## Loop through all the cities in the list.
#for i, city in enumerate(cities):
#
#    # Group cities in sets of 50 for logging purposes.
#    if (i % 50 == 0 and i >= 50):
#        set_count += 1
#        record_count = 1
#    # Create endpoint URL with each city.
#    city_url = url + "&q=" + city.replace(" ","+")
#
#    # Log the URL, record, and set numbers and the city.
#    print(f"Processing Record {record_count} of Set {set_count} | {city}")
#    # Add 1 to the record count.
#    record_count += 1
#    
#    # Run an API request for each of the cities.
#    try:
#        # Parse the JSON and retrieve data.
#        city_weather = requests.get(city_url).json()
#        # Parse out the needed data.
#        city_lat = city_weather["coord"]["lat"]
#        city_lng = city_weather["coord"]["lon"]
#        city_max_temp = city_weather["main"]["temp_max"]
#        city_humidity = city_weather["main"]["humidity"]
#        city_clouds = city_weather["clouds"]["all"]
#        city_wind = city_weather["wind"]["speed"]
#        city_country = city_weather["sys"]["country"]
#        # Convert the date to ISO standard.
#        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
#        # Append the city information into city_data list.
#        city_data.append({"City": city.title(),
#                          "Lat": city_lat,
#                          "Lng": city_lng,
#                          "Max Temp": city_max_temp,
#                          "Humidity": city_humidity,
#                          "Cloudiness": city_clouds,
#                          "Wind Speed": city_wind,
#                          "Country": city_country,
#                          "Date": city_date})
#
## If an error is experienced, skip the city.
#    except:
#        print("City not found. Skipping...")
#        pass
#
## Indicate that Data Loading is complete.
#print("-----------------------------")
#print("Data Retrieval Complete      ")
#print("-----------------------------")

# %%
len(city_data)
# Out:
# 675

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City      Lat      Lng  Max Temp          Weather Desc  Humidity  \
# 0  Hambantota   6.1241  81.1185     77.00  heavy intensity rain       100
# 1     Ushuaia -54.8000 -68.3000     50.00            few clouds        34
# 2     Ludvika  60.1496  15.1878     45.00       overcast clouds        45
# 3    Botucatu -22.8858 -48.4450     76.80             clear sky        41
# 4    Kalengwa -13.4659  25.0027     67.08         broken clouds        73
#
#    Cloudiness  Wind Speed Country                 Date
# 0          40        3.44      LK  2021-04-14 17:25:51
# 1          20       14.97      AR  2021-04-14 17:24:04
# 2          90        5.75      SE  2021-04-14 17:25:10
# 3           1        8.01      BR  2021-04-14 17:25:52
# 4          80        5.41      ZM  2021-04-14 17:25:52

# %%
city_data_df = city_data_df[["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Weather Desc",]]
city_data_df
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Hambantota      LK   6.1241   81.1185     77.00       100          40
# 1       Ushuaia      AR -54.8000  -68.3000     50.00        34          20
# 2       Ludvika      SE  60.1496   15.1878     45.00        45          90
# 3      Botucatu      BR -22.8858  -48.4450     76.80        41           1
# 4      Kalengwa      ZM -13.4659   25.0027     67.08        73          80
# ..          ...     ...      ...       ...       ...       ...         ...
# 670    Bardiyah      LY  31.7561   25.0865     64.47        63          48
# 671   Vetapalem      IN  15.7833   80.3167     84.99        74          90
# 672   Kilindoni      TZ  -7.9139   39.6668     80.96        76         100
# 673      Marawi      PH   7.9986  124.2928     75.99        87         100
# 674     Talnakh      RU  69.4865   88.3972     -1.32        92          85
#
#      Wind Speed          Weather Desc
# 0          3.44  heavy intensity rain
# 1         14.97            few clouds
# 2          5.75       overcast clouds
# 3          8.01             clear sky
# 4          5.41         broken clouds
# ..          ...                   ...
# 670       12.91      scattered clouds
# 671       12.26  heavy intensity rain
# 672       15.86       overcast clouds
# 673        4.00       overcast clouds
# 674        2.10       overcast clouds
#
# [675 rows x 9 columns]

# %%
# store df into a csv file
city_data_df.to_csv("WeatherPy_Database.csv")
